# %%
# import package:

# %%
using Pkg

# %%
Pkg.add("Plots")
# Out:
#    Resolving package versions...
#   No Changes to `~/.julia/environments/v1.9/Project.toml`
#   No Changes to `~/.julia/environments/v1.9/Manifest.toml`

# %%
using Plots

# %%
# line plot: empty plot

# %%
plot()

# %%
x= 1:15; y= rand(15);

# %%
plot(x,y)

# %%
z=rand(15);

# %%
# adding another line to line plot

# %%
plot!(x,z)

# %%
p= plot(x,y)
plot!(p,x,z)

# %%
# adding title to the plot:

# %%
plot(x,y, title="random line plot")

# %%
plot(x,y, title="Random line chart", label="Line Chart 1")

# %%
plot(x,y,xlabel="X axis label", ylabel="Y axis label")

# %%
# scatter chart

# %%
scatter(x,y)

# %%
#bar chart

# %%
bar(x,y)

# %%
#histogram

# %%
histogram(y)

# %%
# create dashboard:

# %%
p1=plot(x,y)
p2=scatter(x,y)
p3=bar(x,y)
p4=histogram(y)

plot(p1,p2, p3, p4, layout=(2,2), legend=false)

# %%
y = rand(15,4)
plot(x,y,layout=(4,1))

# %% [markdown]
# # Plot with DataFrame :

# %%
using CSV
using DataFrames

# %%
Pkg.add("DataFrames")
# Out:
#    Resolving package versions...
#   No Changes to `~/.julia/environments/v1.9/Project.toml`
#   No Changes to `~/.julia/environments/v1.9/Manifest.toml`

# %%
iris= CSV.read("iris.csv", DataFrame)
# Out:
# 149×5 DataFrame
#  Row │ 5.1      3.5      1.4      0.2      Iris-setosa
#      │ Float64  Float64  Float64  Float64  String15
# ─────┼────────────────────────────────────────────────────
#    1 │     4.9      3.0      1.4      0.2  Iris-setosa
#    2 │     4.7      3.2      1.3      0.2  Iris-setosa
#    3 │     4.6      3.1      1.5      0.2  Iris-setosa
#    4 │     5.0      3.6      1.4      0.2  Iris-setosa
#    5 │     5.4      3.9      1.7      0.4  Iris-setosa
#    6 │     4.6      3.4      1.4      0.3  Iris-setosa
#    7 │     5.0      3.4      1.5      0.2  Iris-setosa
#    8 │     4.4      2.9      1.4      0.2  Iris-setosa
#    9 │     4.9      3.1      1.5      0.1  Iris-setosa
#   10 │     5.4      3.7      1.5      0.2  Iris-setosa
#   11 │     4.8      3.4      1.6      0.2  Iris-setosa
#   ⋮  │    ⋮        ⋮        ⋮        ⋮           ⋮
#  140 │     6.7      3.1      5.6      2.4  Iris-virginica
#  141 │     6.9      3.1      5.1      2.3  Iris-virginica
# ...

# %%
names(iris)
# Out:
# 5-element Vector{String}:
#  "5.1"
#  "3.5"
#  "1.4"
#  "0.2"
#  "Iris-setosa"

# %%
rename!(iris, ["Sepal_Length", "Sepal_Width", "Petal_Length","Petal_Width","Iris"])
# Out:
# 149×5 DataFrame
#  Row │ Sepal_Length  Sepal_Width  Petal_Length  Petal_Width  Iris
#      │ Float64       Float64      Float64       Float64      String15
# ─────┼──────────────────────────────────────────────────────────────────────
#    1 │          4.9          3.0           1.4          0.2  Iris-setosa
#    2 │          4.7          3.2           1.3          0.2  Iris-setosa
#    3 │          4.6          3.1           1.5          0.2  Iris-setosa
#    4 │          5.0          3.6           1.4          0.2  Iris-setosa
#    5 │          5.4          3.9           1.7          0.4  Iris-setosa
#    6 │          4.6          3.4           1.4          0.3  Iris-setosa
#    7 │          5.0          3.4           1.5          0.2  Iris-setosa
#    8 │          4.4          2.9           1.4          0.2  Iris-setosa
#    9 │          4.9          3.1           1.5          0.1  Iris-setosa
#   10 │          5.4          3.7           1.5          0.2  Iris-setosa
# ...

# %%
#line chart:
plot( iris.Sepal_Length)

# %%
#bar chart:

# %%
bar(iris.Iris, iris.Petal_Width)

# %%
scatter(iris.Petal_Length, iris.Petal_Width)

# %%
histogram(iris.Petal_Length)
